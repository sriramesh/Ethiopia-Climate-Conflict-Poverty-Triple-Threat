# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

from mpl_toolkits.basemap import Basemap
import folium
from folium.plugins import MarkerCluster

# %%
# Importing Modules
eth = gpd.read_file('Data/ETH-GADM-Adm-Boundaries/gadm36_ETH_1.shp')

eth_refugee_camps = gpd.read_file('Data/ETH-refugee-campsites/Eth_refugee_camps_unhcr_2019.shp')

base = eth_refugee_camps.plot(marker='o', color='green', markersize=10)
eth.plot(ax=base)

plt.title('Ethiopia Refugee Campsites')
plt.show()
